# %% [markdown]
# #### **Problem 01**
#
# What is the output of the following program? Write the output in the empty space below before running the code.
#
# ```python
# amount = 42000
# member = "yes"
# coupon = "no"
#
# if amount >= 50000:
#     discount = 25
# else:
#     if amount >= 30000:
#         discount = 15
#         if member == "yes":
#             discount += 5
#     else:
#         discount = 5
#
# if coupon == "yes":
#     discount += 3
#
# payable = amount - amount * discount / 100
# print(discount)
# print(payable)
# ```
#
# **Answer:**
#
# ```console
#
# ```
#
# Now trace the output again for these cases:
#
# 1. `amount = 60000`, `member = "no"`, `coupon = "yes"`
# 2. `amount = 25000`, `member = "yes"`, `coupon = "yes"`

# %% [markdown]
# #### **Problem 02**
#
# The following program has syntax and logical errors. Underline the erroneous lines and rewrite the corrected program in the code cell.
#
# ```python
# age = int(input("Age: "))
# day = input("Day: ")
#
# if age < 5
#     price = 0
# elif age >= 5 and age <= 18:
#     price == 8
# elif age >= 19 and age <= 60:
#     if day = "Friday":
#         price = 10
#     else
#         price = 12
# else:
#     price = 6
#
# print("Ticket price:", prices)
# ```
#
# The corrected program should follow these rules:
#
# 1. Age below `5`: free ticket.
# 2. Age `5` to `18`: ticket price `8`.
# 3. Age `19` to `60`: ticket price `10` on Friday, otherwise `12`.
# 4. Age above `60`: ticket price `6`.

# %%
# Write your code here

# %% [markdown]
# #### **Problem 03**
#
# Write a Python program to input electricity units consumed and calculate the total electricity bill according to the following conditions:
#
# - For first 50 units: Rs. 0.50/unit
# - For next 100 units: Rs. 0.75/unit
# - For next 100 units: Rs. 1.20/unit
# - For units above 250: Rs. 1.50/unit
# - An additional surcharge of 20% is added to the bill
#
# **Sample Input:**
#
# ```console
# Enter total units consumed: 150
# ```
#
# **Sample Output:**
#
# ```console
# Electricity Bill = Rs. 120.00
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 04**
#
# IUB is selecting students for a study grant. You are requested to write a Python program to help decide whether a student will receive the grant and how much grant money the student will receive.
#
# Your program will take the following inputs:
#
# 1. CGPA of the student
# 2. Number of completed credits
# 3. Monthly family income
# 4. Whether the student has any academic warning (`yes` or `no`)
#
# The selection policy is as follows:
#
# 1. If the student has academic warning, the student is not eligible.
# 2. If the student has no warning, then check CGPA and completed credits.
# 3. To be eligible, the student must have CGPA at least `3.50` and completed credits at least `45`.
# 4. If the student is eligible and family income is below `30000`, the grant amount is `25000` BDT.
# 5. If the student is eligible and family income is from `30000` to `60000`, the grant amount is `15000` BDT.
# 6. If the student is eligible and family income is above `60000`, the grant amount is `5000` BDT.
#
# **Sample Input:**
#
# ```console
# CGPA: 3.72
# Completed credits: 61
# Family income: 42000
# Has warning: no
# ```
#
# **Sample Output:**
#
# ```console
# Eligible
# Grant amount: 15000 BDT
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 05**
#
# Write a program to calculate the fare of a destination from IUB using bike or car. Take all necessary user inputs to run the program successfully.
#
# For a bike ride, the fare is calculated as follows:
#
# ```python
# Bike fare = booking fee + 15 tk per KM + 3 tk per minute wait + 1 tk surcharge per minute wait
# ```
#
# For a car ride, the fare is calculated as follows:
#
# ```python
# Car fare = booking fee + 25 tk per KM + 5 tk per minute wait + 2 tk surcharge per minute wait
# ```
#
# After calculating the fare, apply the following extra condition:
#
# 1. If the ride is at night, add 10% night charge.
# 2. If the ride is during the day, no extra charge is added.
# 3. If the vehicle type is neither `bike` nor `car`, print `Invalid vehicle type`.
#
# **Sample Input:**
#
# ```console
# Vehicle type: car
# Booking fee: 80
# Distance in KM: 8
# Waiting time in minutes: 5
# Ride time: night
# ```
#
# **Sample Output:**
#
# ```console
# Total fare: 346.5 BDT
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 06**
#
# A country has currency denominations of `1000`, `500`, `100`, `50`, `10`, `5`, `1`, `0.25`, `0.10`, `0.05`, and `0.01`.
#
# Write a program that takes a money amount as input and breaks it into the largest possible denominations.
#
# **Caution:** There is no denomination of `20.00`.
#
# **Sample Input:**
#
# ```console
# Enter the money amount: 5731.68
# ```
#
# **Sample Output:**
#
# ```console
# 5 x 1000
# 1 x 500
# 2 x 100
# 3 x 10
# 1 x 1
# 2 x 0.25
# 1 x 0.10
# 1 x 0.05
# 3 x 0.01
# ```
#
# **Hint:** You may solve this using repeated `if` statements. Later, try solving it again using a list of denominations.

# %%
# Write your code here

# %% [markdown]
# #### **Problem 07**
#
# Consider the grading system used by the [Ministry of Education](http://www.educationboard.gov.bd/computer/grading_system.php).
#
# For simplicity, assume there are only three subjects: Bangla, English, and Math. Take three inputs as the scores of a student in those subjects. Find the letter grade and grade point for each subject. Then calculate the final grade point by averaging the three grade points.
#
# **Sample Input:**
#
# ```console
# Enter your score in Bangla: 85
# Enter your score in English: 80
# Enter your score in Math: 70
# ```
#
# **Sample Output:**
#
# ```console
# You got A+ on Bangla
# You got A+ on English
# You got A on Math
# Your final grade is 4.67
# ```
#
# **Hint:** First solve grading for one subject. Then repeat the decision structure for the other subjects.

# %%
# Write your code here

# %% [markdown]
# #### **Problem 08**
#
# You have been offered two tuitions and need to decide which one to pick. All of the following criteria must be met for a tuition to be considered viable:
#
# 1. The tuition must pay at least BDT `8000` per month.
# 2. The tuition must be within `5` kilometers of your residence.
# 3. If any of the above criteria is not met, reject that tuition and consider the other one.
# 4. If both tuitions fail the criteria, reject both.
# 5. If both are viable, accept the tuition that pays the highest. If both pay the same, pick the one that is closest to your house.
#
# **Sample Run 1:**
#
# ```console
# Enter the monthly salary of first tuition: BDT 6000
# Enter the distance of the first tuition from residence: 1500
# Enter the monthly salary of second tuition: BDT 9500
# Enter the distance of the second tuition from residence: 2200
#
# You should pick Tuition Offer 2.
# ```
#
# **Sample Run 2:**
#
# ```console
# Enter the monthly salary of first tuition: BDT 9000
# Enter the distance of the first tuition from residence: 1500
# Enter the monthly salary of second tuition: BDT 9000
# Enter the distance of the second tuition from residence: 2200
#
# You should pick Tuition Offer 1.
# ```

# %%
# Write your code here
