# %% [markdown]
# #### **Problem 01**
#
# Write a program that takes the names of students present in a tutorial class and stores them in a list. First take the number of students, then take each name as input. Print the attendance sheet with serial numbers using `enumerate`. Finally, print the first student, last student, and the list in reverse order using slicing.
#
# **Sample Input:**
#
# ```console
# Enter number of students: 4
# Enter name: Asha
# Enter name: Rafi
# Enter name: Mitu
# Enter name: Sami
# ```
#
# **Sample Output:**
#
# ```console
# Attendance Sheet
# 1. Asha
# 2. Rafi
# 3. Mitu
# 4. Sami
# First student: Asha
# Last student: Sami
# Reverse order: ['Sami', 'Mitu', 'Rafi', 'Asha']
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 02**
#
# A teacher wants to search attendance records. Take `N` student names as input and store them in a list. Then take one name to search. Print how many times the name appears. If the name is found, print its first index using `index`; otherwise print `Not found`. Also print every position where the name appears using `enumerate`.
#
# **Sample Input:**
#
# ```console
# Enter number of names: 5
# Enter name: Rafi
# Enter name: Mitu
# Enter name: Rafi
# Enter name: Sami
# Enter name: Rafi
# Search name: Rafi
# ```
#
# **Sample Output:**
#
# ```console
# Names: ['Rafi', 'Mitu', 'Rafi', 'Sami', 'Rafi']
# Rafi appears 3 times
# First index: 0
# Found at positions: 1 3 5
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 03**
#
# A course teacher stores quiz marks in a list. Take the number of students and then take each quiz mark as input. Use `append` to build the list. Print the original list, sorted list, highest mark, lowest mark, average mark, and the student number of every student who got the highest mark. Use `enumerate` for student numbers.
#
# **Sample Input:**
#
# ```console
# Enter number of students: 5
# Enter mark: 8
# Enter mark: 10
# Enter mark: 7
# Enter mark: 10
# Enter mark: 6
# ```
#
# **Sample Output:**
#
# ```console
# Original marks: [8, 10, 7, 10, 6]
# Sorted marks: [6, 7, 8, 10, 10]
# Highest mark: 10
# Lowest mark: 6
# Average mark: 8.2
# Highest mark found for student numbers: 2 4
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 04**
#
# Write a program for a small shop that stores daily sales amounts in a list. Take `N` sales amounts as input. Without using `sum`, `max`, or `min`, use loops to calculate the total sale, highest sale, lowest sale, and average sale. You may use `sorted` only to print the sales amounts in ascending order.
#
# **Sample Input:**
#
# ```console
# Enter number of days: 4
# Enter sale: 1200
# Enter sale: 850
# Enter sale: 1500
# Enter sale: 1000
# ```
#
# **Sample Output:**
#
# ```console
# Sales: [1200, 850, 1500, 1000]
# Sorted sales: [850, 1000, 1200, 1500]
# Total sale: 4550
# Highest sale: 1500
# Lowest sale: 850
# Average sale: 1137.5
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 05**
#
# Write a program that takes a sentence and removes all vowels from it. Convert the sentence into a list of characters first. Use a loop to build another list that contains only the non-vowel characters. Then print the updated character list and the final sentence using `join`.
#
# **Sample Input:**
#
# ```console
# Enter sentence: We love Python
# ```
#
# **Sample Output:**
#
# ```console
# Updated list: ['W', ' ', 'l', 'v', ' ', 'P', 'y', 't', 'h', 'n']
# Vowels removed: 4
# Final sentence: W lv Pythn
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 06**
#
# A list contains scores from a programming contest. Write a program that prints the list in descending order using `sorted`, counts how many times the target score appears, and prints all positions of the target score using `enumerate`.
#
# ```python
# numbers = [12, 4, 25, 12, 1, 9, 20.5, 99.12, 6, 13, 12]
# ```
#
# **Sample Input:**
#
# ```console
# Enter target score: 12
# ```
#
# **Sample Output:**
#
# ```console
# Descending list: [99.12, 25, 20.5, 13, 12, 12, 12, 9, 6, 4, 1]
# 12 appears 3 times
# Positions: 1 4 11
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 07**
#
# A shopping list already contains some items. Take one new item and add it using `append`. Then take one item name to remove. If the item exists, remove it using `remove`; otherwise print `Item not found`. Finally, print the updated shopping list with serial numbers using `enumerate`.
#
# ```python
# items = ["rice", "egg", "milk"]
# ```
#
# **Sample Input:**
#
# ```console
# Enter item to add: bread
# Enter item to remove: egg
# ```
#
# **Sample Output:**
#
# ```console
# Updated shopping list:
# 1. rice
# 2. milk
# 3. bread
# Total items: 3
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 08**
#
# A class representative records votes for the class captain. Take `N` votes as input and store the candidate names in a list. Print each candidate once with the number of votes received. Do not use a dictionary. Use nested loops and another list to remember which names have already been printed.
#
# **Sample Input:**
#
# ```console
# Enter number of votes: 6
# Enter vote: Rafi
# Enter vote: Mitu
# Enter vote: Rafi
# Enter vote: Sami
# Enter vote: Mitu
# Enter vote: Rafi
# ```
#
# **Sample Output:**
#
# ```console
# Vote count:
# Rafi: 3
# Mitu: 2
# Sami: 1
# ```

# %%
# Write your code here
