# %% [markdown]
# #### **Problem 01**
#
# Trace the output of the following custom-function program. It uses required arguments, default arguments, `*args`, and return values.
#
# ```python
# def mix(a, b=2, *extra):
#     total = a + b
#     for value in extra:
#         total += value
#     return total
#
# print(mix(5, 3, 2, 1))
# print(mix(4))
# print(mix(1, 2, 3, 4, 5))
# ```

# %% [markdown]
# #### **Problem 02**
#
# The following function program has syntax, parameter, logic, and return-value mistakes. Rewrite the corrected program.
#
# ```python
# def compute_lcm(x)
#     lcm = (x * y) // compute_gcd(x, y)
#     return
#
# def compute_gcd(x, y):
#     while y:
#         x = y
#         y = x % y
#     return x
#
# print(compute_lcm(54, 24))
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 03**
#
# Write two functions:
#
# - `odd_even(number)` returns the string `even` or `odd`
# - `prime_status(number)` returns the string `prime` or `not prime`
#
# Take 5 integers from the user and print both results for each integer.

# %%
# Write your code here

# %% [markdown]
# #### **Problem 04**
#
# Write a function named `calculate_fare(distance)` that returns the total ride fare. Use this pricing rule:
#
# - First 5 KM: 50 BDT per KM
# - Next 20 KM: 35 BDT per KM
# - Distance beyond 25 KM: 25 BDT per KM plus 1 BDT surcharge per KM beyond 25
#
# Take distance as input, call the function, and print the fare.

# %%
# Write your code here

# %% [markdown]
# #### **Problem 05**
#
# A list is mutable. When a list is sent as a parameter, changing the list inside the function also changes the original list outside.
#
# First trace the output:
#
# ```python
# def update_marks(marks):
#     marks.append(100)
#     marks[0] = marks[0] + 5
#     print("Inside function:", marks)
#
# quiz_marks = [10, 20, 30]
# update_marks(quiz_marks)
# print("Outside function:", quiz_marks)
# ```
#
# Then write a function named `curve_marks(marks, bonus)` that adds `bonus` to every mark in the same list. Do not return a new list.
#
# ```python
# marks = [35, 40, 28, 50]
# curve_marks(marks, 5)
# print(marks)
# ```
#
# Expected output:
#
# ```console
# [40, 45, 33, 55]
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 06**
#
# Write a function named `list_report(values)` that receives a list of numbers and returns four values: total, average, highest, and lowest. Do not use `sum`, `max`, or `min` inside the function.
#
# **Sample Function Call:**
#
# ```python
# total, average, highest, lowest = list_report([8, 10, 7, 10, 6])
# print(total, average, highest, lowest)
# ```
#
# **Sample Output:**
#
# ```console
# 41 8.2 10 6
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 07**
#
# Write a function named `invoice(customer, *prices, **details)`. The function should:
#
# - Print the customer name
# - Calculate and print the total price from `*prices`
# - Print every extra detail from `**details`
#
# Do not use `sum()` for calculating the total.
#
# **Sample Function Call:**
#
# ```python
# invoice("Rafi", 120, 80, 50, mobile="01700000000", payment="Cash")
# ```
#
# **Sample Output:**
#
# ```console
# Customer: Rafi
# Total price: 250
# mobile: 01700000000
# payment: Cash
# ```

# %%
# Write your code here

# %% [markdown]
# #### **Problem 08**
#
# Explain the scope problem in the following code, then rewrite it correctly. Your corrected version must show the difference between local and global variables.
#
# ```python
# counter = 0
#
# def add_one():
#     counter += 1
#     print(counter)
#
# def show_local():
#     total = 10
#     total += 5
#
# add_one()
# show_local()
# print(total)
# ```

# %%
# Write your code here
